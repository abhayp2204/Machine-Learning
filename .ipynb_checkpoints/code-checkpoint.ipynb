# %%
import pickle
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
# Depickle
pickle_in = open("data/train.pkl", "rb")
result = pickle.load(pickle_in)

# %%
# Convert to numpy array and display the first 5 elements
train_set_full = np.array(result)
train_set_full[:5]
# Out:
# array([[ 2.74276567e+01,  3.33578295e+03],
#        [-4.96183456e+00,  2.64740265e+03],
#        [-2.78611955e+01,  5.20733695e+02],
#        [-1.53463398e+01,  3.51892491e+03],
#        [ 2.86732690e+00, -3.21770068e+03]])

# %%
# Shuffle the dataset
np.random.shuffle(train_set_full)
train_set_full
# Out:
# array([[   17.12779623,  2642.41238221],
#        [   12.67863512, -1660.80998868],
#        [  -21.9138612 , -3290.91229403],
#        ...,
#        [   11.58724046, -1116.439204  ],
#        [  -13.14070509,  1795.7790798 ],
#        [   26.87965742,  -484.32437285]])

# %%
# Separate the dataset
n = 16
train_sets = np.split(train_set_full, n)
train_sets[0][:3]
# Out:
# array([[   17.12779623,  2642.41238221],
#        [   12.67863512, -1660.80998868],
#        [  -21.9138612 , -3290.91229403]])

# %%
# Linear regression algorithm
l_reg = linear_model.LinearRegression()

# %%
for train_set in train_sets:
    # Separate the feature(s) and labels
    X = train_set[:, 0]
    y = train_set[:, 1]
    
    # Convert 1d array to 2d array (train_test_split requires X to be 2 dimensional)
    X = np.reshape(X, (len(X), 1))
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    model = l_reg.fit(X_train, y_train)
    predictions = model.predict(X_test)
    
    # Plot graph
    plt.scatter(X_test, y_test, color='blue')
    plt.plot(X_test, predictions, color='black')
    plt.show()
    
    # Accuracy of the model
    print("R^2 Value: ", l_reg.score(X, y))
# Out:
# R^2 Value:  0.23087609194845993
# R^2 Value:  0.3067524705929189
# R^2 Value:  0.19061357676992208
# R^2 Value:  0.21633275031100463
# R^2 Value:  0.2804880163925403
# R^2 Value:  0.22965727456235996
# R^2 Value:  0.2837983367644419
# R^2 Value:  0.17486996701616242
# R^2 Value:  0.20080347445293034
# R^2 Value:  0.28349177594250496
# R^2 Value:  0.2571701121563361
# R^2 Value:  0.28369876517630443
# R^2 Value:  0.2570181139720038
# R^2 Value:  0.26086983967964283
# R^2 Value:  0.2540222205427233
# R^2 Value:  0.1959923916472942
