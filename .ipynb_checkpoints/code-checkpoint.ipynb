# %%
import pickle
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
# Depickle
pickle_in = open("data/train.pkl", "rb")
result = pickle.load(pickle_in)

# %%
# Convert to numpy array and display the first 5 elements
train_set_full = np.array(result)
train_set_full[:5]
# Out:
# array([[ 2.74276567e+01,  3.33578295e+03],
#        [-4.96183456e+00,  2.64740265e+03],
#        [-2.78611955e+01,  5.20733695e+02],
#        [-1.53463398e+01,  3.51892491e+03],
#        [ 2.86732690e+00, -3.21770068e+03]])

# %%
# Shuffle the dataset
np.random.shuffle(train_set_full)
train_set_full
# Out:
# array([[   17.12779623,  2642.41238221],
#        [   12.67863512, -1660.80998868],
#        [  -21.9138612 , -3290.91229403],
#        ...,
#        [   11.58724046, -1116.439204  ],
#        [  -13.14070509,  1795.7790798 ],
#        [   26.87965742,  -484.32437285]])

# %%
# Separate the dataset
n = 16
train_sets = np.split(train_set_full, n)
train_sets[0][:3]
# Out:
# array([[   17.12779623,  2642.41238221],
#        [   12.67863512, -1660.80998868],
#        [  -21.9138612 , -3290.91229403]])

# %%
for train_set in train_sets:
    X = train_set[:, 0]
    y = train_set[:, 1]
    
#     plt.scatter(X, y)
#     plt.show()

    l_reg = linear_model.LinearRegression()
    
    X = np.reshape(X, (len(X), 1))
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    model = l_reg.fit(X_train, y_train)
    
    predictions = model.predict(X_test)
    
    plt.scatter(X_test, y_test, color='blue')
    plt.plot(X_test, predictions, color='black')
    plt.show()
    
    print("R^2 Value: ", l_reg.score(X, y))
# Out:
# R^2 Value:  0.2316996918465304
# R^2 Value:  0.30644214960084804
# R^2 Value:  0.191395908043845
# R^2 Value:  0.2176567166897757
# R^2 Value:  0.2803674463216762
# R^2 Value:  0.22924092673333363
# R^2 Value:  0.28368496199178583
# R^2 Value:  0.17367178934776573
# R^2 Value:  0.20014774677279112
# R^2 Value:  0.28319511306416745
# R^2 Value:  0.25785702184215087
# R^2 Value:  0.28325742265837994
# R^2 Value:  0.25559917405042076
# R^2 Value:  0.2600906919359237
# R^2 Value:  0.2541445864147922
# R^2 Value:  0.19626825687619798
