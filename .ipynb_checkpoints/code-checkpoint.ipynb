# %%
import pickle
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
# Depickle
pickle_in = open("data/train.pkl", "rb")
result = pickle.load(pickle_in)

# %%
# Convert to numpy array and display the first 5 elements
train_set_full = np.array(result)
train_set_full[:5]
# Out:
# array([[ 2.74276567e+01,  3.33578295e+03],
#        [-4.96183456e+00,  2.64740265e+03],
#        [-2.78611955e+01,  5.20733695e+02],
#        [-1.53463398e+01,  3.51892491e+03],
#        [ 2.86732690e+00, -3.21770068e+03]])

# %%
# Shuffle the dataset
np.random.shuffle(train_set_full)
train_set_full
# Out:
# array([[   17.12779623,  2642.41238221],
#        [   12.67863512, -1660.80998868],
#        [  -21.9138612 , -3290.91229403],
#        ...,
#        [   11.58724046, -1116.439204  ],
#        [  -13.14070509,  1795.7790798 ],
#        [   26.87965742,  -484.32437285]])

# %%
# Separate the dataset
n = 16
train_sets = np.split(train_set_full, n)
train_sets[0][:3]
# Out:
# array([[   17.12779623,  2642.41238221],
#        [   12.67863512, -1660.80998868],
#        [  -21.9138612 , -3290.91229403]])

# %%
for train_set in train_sets:
    X = train_set[:, 0]
    y = train_set[:, 1]
    
    plt.scatter(X, y)
    plt.show()

    l_reg = linear_model.LinearRegression()
    
    X = np.reshape(X, (len(X), 1))
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    model = l_reg.fit(X_train, y_train)
    
    predictions = model.predict(X_test)
    
    print("R^2 Value: ", l_reg.score(X, y))
# Out:
# R^2 Value:  0.23197881837121903
# R^2 Value:  0.30532903299964187
# R^2 Value:  0.1897274988825448
# R^2 Value:  0.21699204191589372
# R^2 Value:  0.28061130363416975
# R^2 Value:  0.2294763093154385
# R^2 Value:  0.28380192571345075
# R^2 Value:  0.17533802663796816
# R^2 Value:  0.20066834456686855
# R^2 Value:  0.28264634314167003
# R^2 Value:  0.2570135310634676
# R^2 Value:  0.28322022160365723
# R^2 Value:  0.2575307729480504
# R^2 Value:  0.2600141964565823
# R^2 Value:  0.25120706218882904
# R^2 Value:  0.19571961046474995
