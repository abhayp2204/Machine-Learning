# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import ShuffleSplit

# %%
# Depickle
pickle_in = open("data/train.pkl", "rb")
result = pickle.load(pickle_in)

# %%
# Convert to numpy array and display the first 5 elements
train_set_full = np.array(result)
train_set_full[:5]
# Out:
# array([[ 2.74276567e+01,  3.33578295e+03],
#        [-4.96183456e+00,  2.64740265e+03],
#        [-2.78611955e+01,  5.20733695e+02],
#        [-1.53463398e+01,  3.51892491e+03],
#        [ 2.86732690e+00, -3.21770068e+03]])

# %%
# Shuffle the dataset
np.random.shuffle(train_set_full)
train_set_full
# Out:
# array([[  -23.05559176,  -891.86496467],
#        [   19.82299486, -1064.78828496],
#        [   -7.53284978,  -575.94562101],
#        ...,
#        [   29.33907155,  2558.63187145],
#        [   23.84779002,   -94.79815884],
#        [  -10.48380801,   854.09530046]])

# %%
# Separate the dataset
n = 16
train_set = np.split(train_set_full, n)
train_set[0][:5]
# Out:
# array([[-2.30555918e+01, -8.91864965e+02],
#        [ 1.98229949e+01, -1.06478828e+03],
#        [-7.53284978e+00, -5.75945621e+02],
#        [ 2.23189765e+01, -5.82708155e+03],
#        [ 2.51422654e+00, -2.58952981e+03]])

# %%
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import ShuffleSplit

# %%
# Depickle
pickle_in = open("data/train.pkl", "rb")
result = pickle.load(pickle_in)
# Out:
# array([[  27.42765666, 3335.78295109],
#        [  -4.96183456, 2647.40265244],
#        [ -27.86119551,  520.73369536],
#        ...,
#        [  27.54602153, 1729.42858449],
#        [   8.97475985, 1264.43870071],
#        [ -19.66451461,  -54.2662792 ]])

# %%
# Convert to numpy array and display the first 5 elements
train_data = np.array(result)
train_data[:5]
# Out:
# array([[ 2.74276567e+01,  3.33578295e+03],
#        [-4.96183456e+00,  2.64740265e+03],
#        [-2.78611955e+01,  5.20733695e+02],
#        [-1.53463398e+01,  3.51892491e+03],
#        [ 2.86732690e+00, -3.21770068e+03]])

# %%
# Shuffle the dataset
np.random.shuffle(train_data)
train_data
# Out:
# array([[ 1.13691739e+01,  6.22955026e+02],
#        [ 2.48860268e+00,  2.65959861e+03],
#        [-1.29084222e+01,  2.05947150e+03],
#        ...,
#        [ 3.34719979e+01,  3.79993986e+03],
#        [-2.30436421e+01,  3.10692467e+03],
#        [ 2.66506377e+01,  1.89787775e+02]])

# %%
# Separate the dataset
n = 16
dataset = np.split(train_data, n)
dataset[0][:5]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <module>
#       1 # Separate the dataset
#       2 n = 16
# ----> 3 dataset = np.split(train_data, n)
#       4 dataset[0][:5]
#
# NameError: name 'np' is not defined
