# %%
import pickle
import numpy as np
import pandas as pd

# %%
# Depickle
pickle_in = open("data/train.pkl", "rb")
result = pickle.load(pickle_in)
# Out:
# array([[  27.42765666, 3335.78295109],
#        [  -4.96183456, 2647.40265244],
#        [ -27.86119551,  520.73369536],
#        ...,
#        [  27.54602153, 1729.42858449],
#        [   8.97475985, 1264.43870071],
#        [ -19.66451461,  -54.2662792 ]])

# %%
# Convert to numpy array and display the first 5 elements
train_data = np.array(result)
train_data[:5]
# Out:
# array([[ 2.74276567e+01,  3.33578295e+03],
#        [-4.96183456e+00,  2.64740265e+03],
#        [-2.78611955e+01,  5.20733695e+02],
#        [-1.53463398e+01,  3.51892491e+03],
#        [ 2.86732690e+00, -3.21770068e+03]])

# %%
# Shuffle the dataset
np.random.shuffle(train_data)
train_data[:5]
# Out:
# array([[ 3.23846038e+01,  7.64073064e+03],
#        [ 1.45481377e+01, -1.27080881e+03],
#        [ 1.55029528e+01,  9.68878719e+02],
#        [-6.95503326e+00,  1.29783854e+03],
#        [ 3.22579665e+01,  2.30348494e+03]])

# %%
# Separate the data
area = train_data[:, 0]
cost = train_data[:, 1]
print(area)
print(cost)
# Out:
# [ 32.38460378  14.54813772  15.50295278 ... -14.77205043 -33.0026702
#    3.01786005]
# [ 7640.7306419  -1270.80881378   968.87871923 ... -4360.58462991
#  -7172.96340307  -964.22778367]
